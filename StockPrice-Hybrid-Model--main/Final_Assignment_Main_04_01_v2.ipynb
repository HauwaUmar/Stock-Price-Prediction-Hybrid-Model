# %% [markdown]
# # Stock Forecasting with a Hybrid Deep Learning Model

# %% [markdown]
# # 1.0 Introduction

# %% [markdown]
# #2.0 Data Collection and Preprocessing

# %% [markdown]
# ##2.1 Imports and Configurations

# %%
#Import necessary libraries 
import pandas as pd
# !pip install yfinance
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from time import time
from google.colab import files
import yfinance as yf
import tensorflow as tf
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=DeprecationWarning)
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score
import seaborn as sns
# !pip install transformers
from transformers import BertTokenizer, BertForSequenceClassification
from transformers import pipeline
import multiprocessing as mp
import datetime as dt
from multiprocessing import Process
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yfinance in /usr/local/lib/python3.9/dist-packages (0.2.14)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.22.4)
# Requirement already satisfied: cryptography>=3.3.2 in /usr/local/lib/python3.9/dist-packages (from yfinance) (40.0.1)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.9/dist-packages (from yfinance) (4.9.2)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.9/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.9/dist-packages (from yfinance) (2.3.6)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.9/dist-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.5.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.9/dist-packages (from yfinance) (4.11.2)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.9/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.9/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.9/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26->yfinance) (1.26.15)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.27.4-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 28.3 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 26.9 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.13.4 tokenizers-0.13.3 transformers-4.27.4

# %%
#configure sentiment analysis pipeline
finbert = BertForSequenceClassification.from_pretrained('yiyanghkust/finbert-tone',num_labels=3)
tokenizer = BertTokenizer.from_pretrained('yiyanghkust/finbert-tone')
nlp = pipeline("sentiment-analysis", model = finbert, tokenizer = tokenizer)
sentiment_dict = {'Negative':-1, 'Neutral':0, 'Positive': 1}
ticker_list = ['MSFT','GOOG', 'AMZN','TSLA','NFLX']
#clone git repo into workspace
# !git clone https://github.com/Chenzhang0329/StockPrice-Hybrid-Model-.git
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/533 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/439M [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Cloning into 'StockPrice-Hybrid-Model-'...
# remote: Enumerating objects: 251, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 251 (delta 12), reused 1 (delta 1), pack-reused 225
# Receiving objects: 100% (251/251), 7.44 MiB | 7.68 MiB/s, done.
# Resolving deltas: 100% (118/118), done.

# %% [markdown]
# ## 2.2 Setup of Data Collection Functions

# %%
# Retrieve financial info from active directory and feature engineer to scale the outcomes to the value of the mean sentiment scores *  count^2
from sklearn.preprocessing import MinMaxScaler
def pull_news(ticker):
    path = '/content/StockPrice-Hybrid-Model-/News Data/'+ticker+'_news.csv'
    news_df = pd.read_csv(path)
    news_list = news_df['headline'].to_list()
    print('success1')
    result = nlp(news_list)
    print('success2')
    result = pd.DataFrame(result)
    news_df["sentiment"] = [sentiment_dict[k]for k in result['label']]  
    news_df['date'] = pd.to_datetime(news_df['date'], format = '%d-%m-%Y')
    sentiment = pd.DataFrame()
    sentiment['mean'] = news_df.groupby(by="date")["sentiment"].mean()
    sentiment['count']= news_df.groupby(by='date')['sentiment'].count()
    sentiment['score'] = sentiment['mean'] * (sentiment['count']**2)
    sentiment = sentiment.fillna(0)
    scaler1 = MinMaxScaler()
    sentiment['score'] = scaler1.fit_transform(sentiment[['score']])
    path3 = ticker+'_sentimentscore.csv'
    sentiment.to_csv(path3)  

#retrieve financial information using yfinance
def get_financials(ticker, start):
    time_delt = dt.timedelta(days = 150)
    start_day = start - time_delt
    data = yf.download(str(ticker), start_day)
    data['ticker'] = ticker
    data = data.reset_index()
    print('success!')
    return data

#Caclulate Exponential moving average
def EWMA(data, ndays): 
    EMA = pd.Series(data['close'].ewm(span = ndays, min_periods = ndays - 1).mean(), 
                 name = 'EWMA_' + str(ndays)) 
    data = data.join(EMA) 
    return data

# Calculate Relative Strength Index
def rsi(close, periods = 14):
    
    close_delta = close.diff()

    # Make two series: one for lower closes and one for higher closes
    up = close_delta.clip(lower=0)
    down = -1 * close_delta.clip(upper=0)
    
    ma_up = up.ewm(com = periods - 1, adjust=True, min_periods = periods).mean()
    ma_down = down.ewm(com = periods - 1, adjust=True, min_periods = periods).mean()

    rsi = ma_up / ma_down
    rsi = 100 - (100/(1 + rsi))
    return rsi

# Calculate Bollinger Bands
def BBANDS(data, window):
    MA = data.close.rolling(window).mean()
    SD = data.close.rolling(window).std()
    data['MiddleBand'] = MA
    data['UpperBand'] = MA + (2 * SD) 
    data['LowerBand'] = MA - (2 * SD)
    return data

# Rolling averages for 10,20,50, and 100 days  feature engineering
def prep_financials(df):
    df = pd.DataFrame(df)
    df.set_index('date')
    df['target'] = (df['close'])
    df['10mda'] = df['close'].rolling(10).mean()
    df['20mda'] = df['close'].rolling(20).mean()
    df['50mda'] = df['close'].rolling(50).mean()
    df['100mda'] = df['close'].rolling(100).mean()
    #df['target'] = [1 if df['pct_change'].loc[i] >0.005 else 0 for i in df.index]
    df = EWMA(df, 20)
    df = EWMA(df, 50) 
    df = EWMA(df, 100)
    df['rsi'] = rsi(df['close'])
    df = BBANDS(df, 20)
    #df.drop(['pct_change'], axis=1, inplace=True)
    df.reset_index()
    return df

# %%
#parallel process to calculate all sentiment scores and process sentiment data into csv files
import datetime as dt
if __name__ == "__main__":
    ticker_list = ['MSFT','GOOG', 'AMZN','TSLA','NFLX']
    processes = []
    proc = Process(target=pull_news)
    processes.append(proc)
    proc.start()

    for tick in ticker_list:
        proc = Process(target =pull_news, args=(tick,))
        processes.append(proc)
        proc.start()
    
    for proc in processes:
        proc.join()
# Out:
# Process Process-1:
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# success1
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# TypeError: pull_news() missing 1 required positional argument: 'ticker'
# success1success1
#
# success1success1
# Process Process-4:
# Process Process-3:
# Process Process-2:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-3-dd654ac2ba5f>", line 8, in pull_news
#     result = nlp(news_list)
#   File "<ipython-input-3-dd654ac2ba5f>", line 8, in pull_news
#     result = nlp(news_list)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/text_classification.py", line 155, in __call__
#     result = super().__call__(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/text_classification.py", line 155, in __call__
#     result = super().__call__(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/base.py", line 1090, in __call__
#     outputs = list(final_iterator)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/base.py", line 1090, in __call__
#     outputs = list(final_iterator)
# Process Process-5:
# Process Process-6:
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/pt_utils.py", line 124, in __next__
#     item = next(self.iterator)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/pt_utils.py", line 124, in __next__
#     item = next(self.iterator)
#   File "<ipython-input-3-dd654ac2ba5f>", line 8, in pull_news
#     result = nlp(news_list)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/pt_utils.py", line 125, in __next__
#     processed = self.infer(item, **self.params)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/pt_utils.py", line 125, in __next__
#     processed = self.infer(item, **self.params)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/text_classification.py", line 155, in __call__
#     result = super().__call__(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/base.py", line 1015, in forward
#     model_outputs = self._forward(model_inputs, **forward_params)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/base.py", line 1015, in forward
#     model_outputs = self._forward(model_inputs, **forward_params)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/text_classification.py", line 182, in _forward
#     return self.model(**model_inputs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/base.py", line 1090, in __call__
#     outputs = list(final_iterator)
# Traceback (most recent call last):
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/text_classification.py", line 182, in _forward
#     return self.model(**model_inputs)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/pt_utils.py", line 124, in __next__
#     item = next(self.iterator)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 1562, in forward
#     outputs = self.bert(
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/pt_utils.py", line 125, in __next__
#     processed = self.infer(item, **self.params)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 1562, in forward
#     outputs = self.bert(
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "<ipython-input-3-dd654ac2ba5f>", line 8, in pull_news
#     result = nlp(news_list)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 1020, in forward
#     encoder_outputs = self.encoder(
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/base.py", line 1015, in forward
#     model_outputs = self._forward(model_inputs, **forward_params)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/text_classification.py", line 155, in __call__
#     result = super().__call__(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/text_classification.py", line 182, in _forward
#     return self.model(**model_inputs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 1020, in forward
#     encoder_outputs = self.encoder(
#   File "<ipython-input-3-dd654ac2ba5f>", line 8, in pull_news
#     result = nlp(news_list)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/base.py", line 1090, in __call__
#     outputs = list(final_iterator)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/text_classification.py", line 155, in __call__
#     result = super().__call__(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 610, in forward
#     layer_outputs = layer_module(
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/pt_utils.py", line 124, in __next__
#     item = next(self.iterator)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 610, in forward
#     layer_outputs = layer_module(
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 1562, in forward
#     outputs = self.bert(
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/base.py", line 1090, in __call__
#     outputs = list(final_iterator)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/pt_utils.py", line 125, in __next__
#     processed = self.infer(item, **self.params)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/pt_utils.py", line 124, in __next__
#     item = next(self.iterator)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 537, in forward
#     layer_output = apply_chunking_to_forward(
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pytorch_utils.py", line 248, in apply_chunking_to_forward
#     return forward_fn(*input_tensors)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 495, in forward
#     self_attention_outputs = self.attention(
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/base.py", line 1015, in forward
#     model_outputs = self._forward(model_inputs, **forward_params)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 1020, in forward
#     encoder_outputs = self.encoder(
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/pt_utils.py", line 125, in __next__
#     processed = self.infer(item, **self.params)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 550, in feed_forward_chunk
#     layer_output = self.output(intermediate_output, attention_output)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/base.py", line 1015, in forward
#     model_outputs = self._forward(model_inputs, **forward_params)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/text_classification.py", line 182, in _forward
#     return self.model(**model_inputs)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pipelines/text_classification.py", line 182, in _forward
#     return self.model(**model_inputs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 462, in forward
#     hidden_states = self.dense(hidden_states)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 610, in forward
#     layer_outputs = layer_module(
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 434, in forward
#     attention_output = self.output(self_outputs[0], hidden_states)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 1562, in forward
#     outputs = self.bert(
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 537, in forward
#     layer_output = apply_chunking_to_forward(
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/linear.py", line 114, in forward
#     return F.linear(input, self.weight, self.bias)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 384, in forward
#     hidden_states = self.dense(hidden_states)
# KeyboardInterrupt
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pytorch_utils.py", line 248, in apply_chunking_to_forward
#     return forward_fn(*input_tensors)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 1020, in forward
#     encoder_outputs = self.encoder(
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 1562, in forward
#     outputs = self.bert(
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 549, in feed_forward_chunk
#     intermediate_output = self.intermediate(attention_output)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/linear.py", line 114, in forward
#     return F.linear(input, self.weight, self.bias)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 610, in forward
#     layer_outputs = layer_module(
# KeyboardInterrupt
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 449, in forward
#     hidden_states = self.dense(hidden_states)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 495, in forward
#     self_attention_outputs = self.attention(
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 1020, in forward
#     encoder_outputs = self.encoder(
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/linear.py", line 114, in forward
#     return F.linear(input, self.weight, self.bias)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 610, in forward
#     layer_outputs = layer_module(
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 434, in forward
#     attention_output = self.output(self_outputs[0], hidden_states)
# KeyboardInterrupt
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 537, in forward
#     layer_output = apply_chunking_to_forward(
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 384, in forward
#     hidden_states = self.dense(hidden_states)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/pytorch_utils.py", line 248, in apply_chunking_to_forward
#     return forward_fn(*input_tensors)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 550, in feed_forward_chunk
#     layer_output = self.output(intermediate_output, attention_output)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/linear.py", line 114, in forward
#     return F.linear(input, self.weight, self.bias)
# KeyboardInterrupt
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/transformers/models/bert/modeling_bert.py", line 462, in forward
#     hidden_states = self.dense(hidden_states)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.9/dist-packages/torch/nn/modules/linear.py", line 114, in forward
#     return F.linear(input, self.weight, self.bias)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-3243095f5bbe> in <cell line: 3>()
#      14
#      15     for proc in processes:
# ---> 16         proc.join()
#
# /usr/lib/python3.9/multiprocessing/process.py in join(self, timeout)
#     147         assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148         assert self._popen is not None, 'can only join a started process'
# --> 149         res = self._popen.wait(timeout)
#     150         if res is not None:
#     151             _children.discard(self)
#
# /usr/lib/python3.9/multiprocessing/popen_fork.py in wait(self, timeout)
#      41                     return None
#      42             # This shouldn't block if wait() returned successfully.
# ---> 43             return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#      44         return self.returncode
#      45
#
# /usr/lib/python3.9/multiprocessing/popen_fork.py in poll(self, flag)
#      25         if self.returncode is None:
#      26             try:
# ---> 27                 pid, sts = os.waitpid(self.pid, flag)
#      28             except OSError:
#      29                 # Child process not yet created. See #1731717
#
# KeyboardInterrupt:

# %%
#Complete financial info retrieval
finance_dfs = []
for tick in ticker_list:
    data = get_financials(tick, dt.date(2018,1, 1))
    data.rename(columns = {'Date':'date', 'Open':'open', 'High':'high', 'Low':'low', 'Close':'close','Adj Close': 'adj_close', 'Volume':'volume'}, inplace = True)
    print(data.info())
    prepped = prep_financials(data)
    finance_dfs.append(prepped)

#read finance data to csv
full_finance = pd.concat(finance_dfs)
full_finance.to_csv('finance.csv', index = False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# success!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1430 entries, 0 to 1429
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       1430 non-null   datetime64[ns]
#  1   open       1430 non-null   float64
#  2   high       1430 non-null   float64
#  3   low        1430 non-null   float64
#  4   close      1430 non-null   float64
#  5   adj_close  1430 non-null   float64
#  6   volume     1430 non-null   int64
#  7   ticker     1430 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(1)
# memory usage: 89.5+ KB
# None
# [*********************100%***********************]  1 of 1 completed
# success!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1430 entries, 0 to 1429
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       1430 non-null   datetime64[ns]
#  1   open       1430 non-null   float64
#  2   high       1430 non-null   float64
#  3   low        1430 non-null   float64
#  4   close      1430 non-null   float64
#  5   adj_close  1430 non-null   float64
#  6   volume     1430 non-null   int64
#  7   ticker     1430 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(1)
# memory usage: 89.5+ KB
# None
# [*********************100%***********************]  1 of 1 completed
# success!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1430 entries, 0 to 1429
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       1430 non-null   datetime64[ns]
#  1   open       1430 non-null   float64
#  2   high       1430 non-null   float64
#  3   low        1430 non-null   float64
#  4   close      1430 non-null   float64
#  5   adj_close  1430 non-null   float64
#  6   volume     1430 non-null   int64
#  7   ticker     1430 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(1)
# memory usage: 89.5+ KB
# None
# [*********************100%***********************]  1 of 1 completed
# success!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1430 entries, 0 to 1429
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       1430 non-null   datetime64[ns]
#  1   open       1430 non-null   float64
#  2   high       1430 non-null   float64
#  3   low        1430 non-null   float64
#  4   close      1430 non-null   float64
#  5   adj_close  1430 non-null   float64
#  6   volume     1430 non-null   int64
#  7   ticker     1430 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(1)
# memory usage: 89.5+ KB
# None
# [*********************100%***********************]  1 of 1 completed
# success!
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1430 entries, 0 to 1429
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       1430 non-null   datetime64[ns]
#  1   open       1430 non-null   float64
#  2   high       1430 non-null   float64
#  3   low        1430 non-null   float64
#  4   close      1430 non-null   float64
#  5   adj_close  1430 non-null   float64
#  6   volume     1430 non-null   int64
#  7   ticker     1430 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(1)
# memory usage: 89.5+ KB
# None

# %% [markdown]
# #  3.0 Exploratory Data Analysis(EDA) and Data Cleaning
# All data collection and initial prep is completed at this point.

# %%
#retrieve sentiment scores and create dataframes with only score and date columns
sentiment_dfs = []
for i in ticker_list:
  data = pd.read_csv('/content/StockPrice-Hybrid-Model-/Sentiment Score/'+i+'_sentimentscore.csv')
  data['date'] = pd.to_datetime(data['date'])
  df = data[['date','score']]
  sentiment_dfs.append(df)
#Check distribution of sentiment dataframe
print(sentiment_dfs[1].describe())
# Out:
#              score
# count  1410.000000
# mean      0.347804
# std       0.046656
# min       0.000000
# 25%       0.343666
# 50%       0.345013
# 75%       0.349057
# max       1.000000

# %% [markdown]
# ## 3.1 Create Final Dataframes to Include Both Sentiment Data and Financial Data

# %%
financials = pd.read_csv('finance.csv')
#function to separate dataframe by company
def separate_companies(ticker, df):
    dataframe = df[df['ticker']==ticker]
    return dataframe

#separate dataframes for each company and add new features
df_list = []
for tick in ticker_list:
    data = separate_companies(tick, financials)
    data.reset_index()
    data['date'] = pd.to_datetime(data['date'])
    df_list.append(data)


goog = df_list[1].set_index('date').join(sentiment_dfs[1].set_index('date'),how = 'left').loc['2018-01-01':'2023-02-01'].fillna(sentiment_dfs[1].mean())
msft = df_list[0].set_index('date').join(sentiment_dfs[0].set_index('date'),how = 'left').loc['2018-01-01':'2023-02-01'].fillna(sentiment_dfs[0].mean())
amzn = df_list[2].set_index('date').join(sentiment_dfs[2].set_index('date'),how = 'left').loc['2018-01-01':'2023-02-01'].fillna(sentiment_dfs[2].mean())
tesla = df_list[3].set_index('date').join(sentiment_dfs[3].set_index('date'),how = 'left').loc['2018-01-01':'2023-02-01'].fillna(sentiment_dfs[3].mean())
nflx = df_list[4].set_index('date').join(sentiment_dfs[4].set_index('date'),how = 'left').loc['2018-01-01':'2023-02-01'].fillna(sentiment_dfs[4].mean())

frames = [goog, msft, amzn, tesla, nflx]
# Out:
# <ipython-input-7-82c985f0176a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['date'])
# <ipython-input-7-82c985f0176a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['date'])
# <ipython-input-7-82c985f0176a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['date'])
# <ipython-input-7-82c985f0176a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['date'])
# <ipython-input-7-82c985f0176a>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['date'])

# %% [markdown]
# ## 3.2 EDA to Explore Change in Stock Prices and Daily Headlines

# %%
#EDA and summary stats for compiled datasets
ticker_list = ['GOOG', 'MSFT','AMZN','TSLA','NFLX']
plt.figure(figsize = (10, 6))
frames = [goog, msft, amzn, tesla, nflx]
#create plot to display change in share price
for i, frame in enumerate(frames):
  frame['close'].plot(label = ticker_list[i]+' Close Price')
plt.ylabel('Share Price')
plt.legend()
plt.show()

#create plot to display daily number of headlines as a 20 day rolling average 
rollings = []
for i, frame in enumerate(frames):
  frame['average headlines'] = frame['headline'].rolling(20).mean()
  rollings.append(frame)
plt.figure(figsize = (12, 8))
for i, frame in enumerate(rollings):
  frame['average headlines'].plot(label = ticker_list[i]+' # Daily Headlines')
plt.legend()
plt.ylabel('20 Day Rolling Average Number of Headlines ')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'headline'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-9b82756f8486> in <cell line: 14>()
#      13 rollings = []
#      14 for i, frame in enumerate(frames):
# ---> 15   frame['average headlines'] = frame['headline'].rolling(20).mean()
#      16   rollings.append(frame)
#      17 plt.figure(figsize = (12, 8))
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'headline'

# %% [markdown]
# ## 3.3 Scale Data and Configure Training/Test Datasets

# %%
from sklearn.preprocessing import MinMaxScaler
# drop irrevelant columns
data = frames[1] # data for microsoft
data = data.drop(['ticker'],axis=1)
 
# features and target columns
target_scaler = MinMaxScaler()
target = target_scaler.fit_transform(data[['target']])
score = data['score']
X_feat = data.drop(['target', 'score'], axis = 1)

# Normalise the data
for col in X_feat.columns:
    scaler = MinMaxScaler(feature_range=(0,1))
    X_feat[col] = scaler.fit_transform(X_feat[[col]])
X_feat['score'] = score
X_ft = np.array(X_feat)
# Creating a data structure with 10 time-steps and 1 output
 
# Split data into X_train and y_train data sets
def lstm_split(data,target,steps):
  X = []
  y = []
  # Creating a data structure with 10 time-steps and 1 output
  for i in range(10, steps):
      X.append(data[i-10:i])
      y.append(target[i])  
  return np.array(X),np.array(y)
 
X1,y1 = lstm_split(X_feat,target,len(X_ft))
 

 # function to split  data 90% training-10% testing
def train_split(x1, y1, train_data):
  split = 0.9
  split_idx = int(np.ceil(len(X1)*split))
  date_index = train_data.index
 
  X_train,X_test = X1[:split_idx],X1[split_idx:]
  y_train,y_test = y1[:split_idx],y1[split_idx:]
  X_train_date,X_test_date = date_index[:split_idx],date_index[split_idx:]
  return X_train, X_test, y_train, y_test
  
X_train, X_test, y_train, y_test = train_split(X1, y1, frames[1])
print(X1.shape,X_train.shape,X_test.shape,y_test.shape,y_train.shape)
# Out:
# (1270, 10, 18) (1143, 10, 18) (127, 10, 18) (127, 1) (1143, 1)

# %% [markdown]
# # 4.0 Single Company Model Implementation
#
# This section contains the necessary code to define our model and train/test the standalone LSTM as well as the hybrid ensemble model.

# %% [markdown]
# ## 4.1 Build  & Validate the LSTM Model on Microsoft Stock
# The general architecture of the model is available below. Specific hyperparameters will be defined during the training process using RandomSearch.

# %%
#LSTM Framework for MSFT
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import LSTM
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.metrics import Precision
from keras.optimizers import Adam
# !pip install keras_tuner
import keras_tuner


#define function to create model, optional hyperparameters included to be selected during training
LR = 0.05
EPOCH = 200
BATCH = 24
def build_model(hp):
  model = Sequential()
  hidden = hp.Choice('n_hidden', [0,1,2,3])
  model.add(LSTM(units = hp.Int('neurons_visible', min_value = X_train.shape[2], max_value = 100, step = 20),
                activation = hp.Choice('activate1', ['sigmoid', 'relu']),
                input_shape = (X_train.shape[1], X_train.shape[2]),
                return_sequences = True if hidden >0 else False))
  
  #Configure hidden layers based on random search determined hidden layer number
  if hidden > 0:
    for num in range(hidden):
      model.add(Dropout(hp.Float('dropout' +str(num+1), min_value = 0.1, max_value = 0.9, step = 0.3)))
      model.add(LSTM(units = hp.Int('neurons_hidden'+str(num+1), min_value = 20, max_value = 50, step = 10),
                     activation = 'relu', return_sequences = True if num != hidden else False))
      
  model.add(Dropout(0.5))
  model.add(Dense(units = 1))

  #compile the model
  model.compile(loss = 'mean_squared_error', optimizer = Adam(lr = LR), metrics = ['mean_squared_error'])
  
  return model

#set learning rate and early stopping callbacks
LR_decay = ReduceLROnPlateau('loss', patience=1, verbose=0, 
                             factor=0.5, min_lr=1e-8)
Early_stop = EarlyStopping(monitor='loss', min_delta=0, 
                           patience=25, verbose=1, mode='auto',
                           baseline=0, restore_best_weights=True)
#arrange random search class
tune = keras_tuner.RandomSearch(build_model, objective= keras_tuner.Objective('val_loss', direction='min'), max_trials = 50, seed = 2)

#complete training 
tune.search(X_train, y_train, epochs = EPOCH, batch_size = BATCH, validation_data = (X_test, y_test), callbacks = [LR_decay, Early_stop])

LSTM_model = tune.get_best_models()[0]

#validating the training
test_predictions = LSTM_model.evaluate(X_train, y_train)
print(test_predictions)
LSTM_model.save('/content/StockPrice-Hybrid-Model-/Models/LSTM_model.h5')
hyperparameters = tune.get_best_hyperparameters(1)[0]
print(hyperparameters.values)
# Out:
# Trial 50 Complete [00h 00m 37s]
# val_loss: 0.04140230640769005
#
# Best val_loss So Far: 0.0008830050937831402
# Total elapsed time: 00h 09m 38s
# 36/36 [==============================] - 1s 4ms/step - loss: 9.3509e-04 - mean_squared_error: 9.3509e-04
# [0.0009350916370749474, 0.0009350916370749474]
# {'n_hidden': 0, 'neurons_visible': 98, 'activate1': 'sigmoid', 'dropout1': 0.4, 'neurons_hidden1': 20, 'dropout2': 0.7, 'neurons_hidden2': 50, 'dropout3': 0.1, 'neurons_hidden3': 50}

# %% [markdown]
# ##4.2 LSTM Model Testing

# %% [markdown]
# ### 4.2.2 Evaluate LSTM Model Success on MSFT Test Data

# %%
# function to test LSTM predictions
def testmodel(m_path, trainset ):
  from keras.models import load_model
  model = load_model(m_path)
  return model.predict(trainset)

# %%
#test LSTM model using X_train for MSFT
LSTM_MSFT_test = testmodel('/content/StockPrice-Hybrid-Model-/Models/LSTM_model.h5', X_test)
LSTM_MSFT_test.shape
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 4/4 [==============================] - 0s 6ms/step
# (127, 1)

# %%
import matplotlib.pyplot as plt
x=np.arange(1,len(y_test)+1, 1)
plt.plot(x,LSTM_MSFT_test.flatten(), "r", label= "Predicted")
plt.plot(x,y_test, "b", label= "Target")

plt.title(" LSTM MSFT Predicted vs target trends")
plt.xlabel('X_test entry')
plt.legend()
plt.show()

# %% [markdown]
# ### 4.2.1 Format Test Data to Reflect Training Data for Google Stock

# %%
# prep google test data
google = frames[0]
google_scaler = MinMaxScaler()
google_target = google_scaler.fit_transform(google[['target']])
google_score = google['score']
test_ft = google.drop(['target', 'score', 'ticker'], axis = 1)

# Normalise the data
for col in test_ft.columns:
    scaler = MinMaxScaler(feature_range=(0,1))
    test_ft[col] = scaler.fit_transform(test_ft[[col]])
test_ft['score'] = google_score
test_ft = np.array(test_ft)

google_ft, google_target = lstm_split(test_ft,google_target,len(test_ft))

# %%
#test LSTM model using X_train for GOOG
LSTM_GOOG_yhat = testmodel('/content/StockPrice-Hybrid-Model-/Models/LSTM_model.h5', google_ft)
LSTM_GOOG_yhat.shape,google_ft.shape
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 40/40 [==============================] - 0s 5ms/step
# ((1270, 1), (1270, 10, 18))

# %%
import matplotlib.pyplot as plt
x=np.arange(1,len(google_target)+1, 1)
plt.plot(x,LSTM_GOOG_yhat.flatten(), "r", label= "Predicted")
plt.plot(x,google_target, "b", label= "Target")

plt.title(" LSTM Google Predicted vs target trends")
plt.xlabel('X_test entry')
plt.legend()
plt.show()

# %% [markdown]
# ##4.3 Prophet Model

# %% [markdown]
# For this section is how we gonna fit the prophet model by using miscosoft company stock price data. The best hyperparameter we get by using the cross-validation

# %%
from prophet import Prophet
from sklearn.metrics import mean_squared_error
from prophet.diagnostics import cross_validation, performance_metrics
from sklearn.model_selection import ParameterGrid

# %%
# Uploaded stock price csv
finance_data = pd.read_csv('/content/StockPrice-Hybrid-Model-/Finance Data/finance.csv')
finance_data
# Out:
#             date        open        high         low       close   adj_close  \
# 0     2017-08-04   72.400002   73.040001   72.239998   72.680000   67.571640
# 1     2017-08-07   72.800003   72.900002   72.260002   72.400002   67.311348
# 2     2017-08-08   72.089996   73.129997   71.750000   72.790001   67.673927
# 3     2017-08-09   72.250000   72.510002   72.050003   72.470001   67.376427
# 4     2017-08-10   71.900002   72.190002   71.349998   71.410004   66.390930
# ...          ...         ...         ...         ...         ...         ...
# 7034  2023-03-03  315.450012  317.489990  310.820007  315.179993  315.179993
# 7035  2023-03-06  317.000000  323.299988  311.839996  312.029999  312.029999
# 7036  2023-03-07  312.679993  314.299988  306.619995  308.470001  308.470001
# 7037  2023-03-08  309.290009  311.829987  305.750000  311.790009  311.790009
# 7038  2023-03-09  312.079987  312.510010  308.920013  311.600006  311.600006
#
#         volume ticker       10mda       20mda     50mda    100mda  target  \
# 0     22579000   MSFT         NaN         NaN       NaN       NaN       0
# 1     18705700   MSFT         NaN         NaN       NaN       NaN       0
# 2     22044600   MSFT         NaN         NaN       NaN       NaN       0
# 3     22213400   MSFT         NaN         NaN       NaN       NaN       0
# 4     24734500   MSFT         NaN         NaN       NaN       NaN       1
# ...        ...    ...         ...         ...       ...       ...     ...
# 7034   5948700   NFLX  324.684000  342.225999  331.8898  307.5842       0
# 7035   5660700   NFLX  321.091000  339.532500  332.3666  308.4047       0
# 7036   4553100   NFLX  318.188000  336.881999  332.5768  309.3465       0
# 7037   3473700   NFLX  315.879001  334.323999  332.8576  310.2557       0
# 7038    607349   NFLX  314.674002  331.562500  333.1904  311.0466       0
#
#          EWMA_20     EWMA_50    EWMA_100        rsi  MiddleBand   UpperBand  \
# 0            NaN         NaN         NaN        NaN         NaN         NaN
# 1            NaN         NaN         NaN        NaN         NaN         NaN
# 2            NaN         NaN         NaN        NaN         NaN         NaN
# 3            NaN         NaN         NaN        NaN         NaN         NaN
# 4            NaN         NaN         NaN        NaN         NaN         NaN
# ...          ...         ...         ...        ...         ...         ...
# 7034  333.354929  329.493002  311.532992  36.602178  342.225999  382.643564
# 7035  331.323984  328.808179  311.542834  35.089691  339.532500  380.483676
# 7036  329.147414  328.010603  311.481986  33.409424  336.881999  378.704750
# 7037  327.494328  327.374501  311.488085  36.464952  334.323999  375.689192
# 7038  325.980583  326.755894  311.490301  36.362120  331.562500  371.125506
#
#        LowerBand
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 7034  301.808435
# 7035  298.581324
# 7036  295.059248
# 7037  292.958806
# 7038  291.999494
#
# [7039 rows x 20 columns]

# %%
MSFT_Data = finance_data[finance_data['ticker']=='MSFT']
Google_Data = finance_data[finance_data['ticker']=='GOOG']
# This function is used to get the train data and test data
def data_preparation(df):
  data=df[["date","adj_close"]]
  data = data.rename(columns = {'date':'ds', 'adj_close':'y'})
  return data

# %%
# Define parameter grid to search over
param_grid = {
    'seasonality_mode': ['additive', 'multiplicative'],
    'changepoint_prior_scale': [0.01, 0.1, 1.0],
    'seasonality_prior_scale': [0.01, 0.1, 1.0],
}

# Initialize minimum error and best parameters
min_error = float('inf')
best_params = {}

# Loop through all parameter combinations
for params in ParameterGrid(param_grid):
    print('Testing parameters:', params)

    # Initialize Prophet model with specified hyperparameters
    model = Prophet(**params)
    model.fit(data_preparation(MSFT_Data))

    # Perform time series cross-validation
    df_cv = cross_validation(model=model, initial='1000 days', horizon='10 days', period='10 days')

    # Calculate performance metrics
    df_metrics = performance_metrics(df_cv)

    # Calculate mean cross-validation error
    mean_cv_error = df_metrics['mse'].mean()

    # Update minimum error and best parameters if new minimum is found
    if mean_cv_error < min_error:
        min_error = mean_cv_error
        best_params = params

# Print best hyperparameters and corresponding error
print('Best parameters:', best_params)
print('Minimum cross-validation error:', min_error)
# Out:
# Testing parameters: {'changepoint_prior_scale': 0.01, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.01}
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/84hinyuv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/8igyetxv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92422', 'data', 'file=/tmp/tmps3g8rtu5/84hinyuv.json', 'init=/tmp/tmps3g8rtu5/8igyetxv.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modelq0u1_6i7/prophet_model-20230411223618.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:36:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:36:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 104 forecasts with cutoffs between 2020-05-03 00:00:00 and 2023-02-27 00:00:00
#   0%|          | 0/104 [00:00<?, ?it/s]
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/d15ajyfa.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/nm2g07f2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=21755', 'data', 'file=/tmp/tmps3g8rtu5/d15ajyfa.json', 'init=/tmp/tmps3g8rtu5/nm2g07f2.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_model2h5pejel/prophet_model-20230411223618.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:36:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:36:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/xuzopn1x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/zu_47fex.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=19745', 'data', 'file=/tmp/tmps3g8rtu5/xuzopn1x.json', 'init=/tmp/tmps3g8rtu5/zu_47fex.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modelcoq5wgr2/prophet_model-20230411223619.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:36:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:36:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/wyu0zhbi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/z18spse3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=82886', 'data', 'file=/tmp/tmps3g8rtu5/wyu0zhbi.json', 'init=/tmp/tmps3g8rtu5/z18spse3.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modelz5lipoyf/prophet_model-20230411223619.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:36:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:36:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/hsmdhrb1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/2pkv0lj1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=65853', 'data', 'file=/tmp/tmps3g8rtu5/hsmdhrb1.json', 'init=/tmp/tmps3g8rtu5/2pkv0lj1.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modeljckaks5p/prophet_model-20230411223619.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:36:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:36:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/h72wlq7p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/wdwygh4o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34630', 'data', 'file=/tmp/tmps3g8rtu5/h72wlq7p.json', 'init=/tmp/tmps3g8rtu5/wdwygh4o.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modelyva8zd3r/prophet_model-20230411223619.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:36:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:36:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/l2z48fvs.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/cixsxpkk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87787', 'data', 'file=/tmp/tmps3g8rtu5/l2z48fvs.json', 'init=/tmp/tmps3g8rtu5/cixsxpkk.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modely_7oy_uq/prophet_model-20230411223620.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:36:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:36:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/1rrykdea.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/3dgv4gn1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73583', 'data', 'file=/tmp/tmps3g8rtu5/1rrykdea.json', 'init=/tmp/tmps3g8rtu5/3dgv4gn1.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modelnv79fq_k/prophet_model-20230411223620.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:36:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:36:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/_awdgul4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/pncivio1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=65882', 'data', 'file=/tmp/tmps3g8rtu5/_awdgul4.json', 'init=/tmp/tmps3g8rtu5/pncivio1.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modelg1hketsm/prophet_model-20230411223620.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:36:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:36:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/p66nlmcx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/1oseb5f0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34287', 'data', 'file=/tmp/tmps3g8rtu5/p66nlmcx.json', 'init=/tmp/tmps3g8rtu5/1oseb5f0.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modely565cvgt/prophet_model-20230411223620.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 22:36:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 22:36:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/8f85o31i.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/xkuxamu1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=
json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_model069cepv6/prophet_model-20230411230132.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:01:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:01:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Best parameters: {'changepoint_prior_scale': 0.1, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0}
# Minimum cross-validation error: 185.1688513042688

# %% [markdown]
# ### 4.3.1 Forecasting with Prophet

# %%
def get_data(df):
  Best_parameters={'changepoint_prior_scale': 0.1, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0}
  # We use the best parameter to fit the model
  final_model = Prophet(**Best_parameters)
  final_model.fit(data_preparation(df))
  df = cross_validation(model=final_model, initial='124 days', horizon='10 days', period='10 days')
  return df

# %%
MSFT_train_data = get_data(MSFT_Data)[['ds', 'yhat']]
MSFT_train_data.head()
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/dgl_xm5u.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/u2lbd8ur.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45154', 'data', 'file=/tmp/tmps3g8rtu5/dgl_xm5u.json', 'init=/tmp/tmps3g8rtu5/u2lbd8ur.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_model_jcjd4q7/prophet_model-20230411230324.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:03:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:03:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 191 forecasts with cutoffs between 2017-12-15 00:00:00 and 2023-02-27 00:00:00
# WARNING:prophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/191 [00:00<?, ?it/s]
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/1a756jlc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/cqqp42ap.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42447', 'data', 'file=/tmp/tmps3g8rtu5/1a756jlc.json', 'init=/tmp/tmps3g8rtu5/cqqp42ap.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modelqtahknwf/prophet_model-20230411230326.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:03:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:03:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/brz7pev5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/e0pxhkg8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=50909', 'data', 'file=/tmp/tmps3g8rtu5/brz7pev5.json', 'init=/tmp/tmps3g8rtu5/e0pxhkg8.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_model5kadxl_b/prophet_model-20230411230331.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:03:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:04:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/novxvbot.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/j7bvw0wu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43023', 'data', 'file=/tmp/tmps3g8rtu5/novxvbot.json', 'init=/tmp/tmps3g8rtu5/j7bvw0wu.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modelgctr_p56/prophet_model-20230411230418.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:04:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:04:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/ka8eesgq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/b21b2x6z.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48432', 'data', 'file=/tmp/tmps3g8rtu5/ka8eesgq.json', 'init=/tmp/tmps3g8rtu5/b21b2x6z.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_model2_1cac30/prophet_model-20230411230419.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:04:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:04:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/6wxxtfhu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/oa6l5gf6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63323', 'data', 'file=/tmp/tmps3g8rtu5/6wxxtfhu.json', 'init=/tmp/tmps3g8rtu5/oa6l5gf6.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modelet2k8w5t/prophet_model-20230411230419.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:04:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:04:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/p2ea0l5a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/kdk6ashy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46812', 'data', 'file=/tmp/tmps3g8rtu5/p2ea0l5a.json', 'init=/tmp/tmps3g8rtu5/kdk6ashy.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modelj9jvyfex/prophet_model-20230411230419.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:04:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:04:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/bpqbcuf9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/g3p2asgo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59208', 'data', 'file=/tmp/tmps3g8rtu5/bpqbcuf9.json', 'init=/tmp/tmps3g8rtu5/g3p2asgo.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_model06gsm5vc/prophet_model-20230411230419.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:04:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:04:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/2kt1qwgq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/vt3qckm0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41932', 'data', 'file=/tmp/tmps3g8rtu5/2kt1qwgq.json', 'init=/tmp/tmps3g8rtu5/vt3qckm0.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modeldbv27tvc/prophet_model-20230411230420.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:04:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:04:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/7xfkdm76.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/dpxxtngp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29820', 'data', 'file=/tmp/tmps3g8rtu5/7xfkdm76.json', 'init=/tmp/tmps3g8rtu5/dpxxtngp.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modelnt3fszzg/prophet_model-20230411230420.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:04:20 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:04:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/cmxwxkt5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/5bplgetu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12625', 'data', 'file=/tmp/tmps3g8rtu5/cmxwxkt5.json', 'init=/tmp/tmps3g8rtu5/5bplgetu.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_mod
csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:07:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:07:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#           ds       yhat
# 0 2017-12-18  73.970595
# 1 2017-12-19  68.597337
# 2 2017-12-20  60.279245
# 3 2017-12-21  49.091784
# 4 2017-12-22  34.894607

# %%
MSFT_train_data.shape
# Out:
# (1314, 2)

# %%
Google_train_data = get_data(Google_Data)[['ds', 'yhat']]
Google_train_data.head()
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/72tuen4p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/v8ytp_t6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=50808', 'data', 'file=/tmp/tmps3g8rtu5/72tuen4p.json', 'init=/tmp/tmps3g8rtu5/v8ytp_t6.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modelyko5nsni/prophet_model-20230411230948.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:09:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 191 forecasts with cutoffs between 2017-12-15 00:00:00 and 2023-02-27 00:00:00
# WARNING:prophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
#   0%|          | 0/191 [00:00<?, ?it/s]
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/jqr4n1jl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/fi639q85.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38263', 'data', 'file=/tmp/tmps3g8rtu5/jqr4n1jl.json', 'init=/tmp/tmps3g8rtu5/fi639q85.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_model3cbgf13a/prophet_model-20230411230950.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/ckdzw_jp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/t1phxblb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6487', 'data', 'file=/tmp/tmps3g8rtu5/ckdzw_jp.json', 'init=/tmp/tmps3g8rtu5/t1phxblb.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modelogbf_8d_/prophet_model-20230411230951.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 23:09:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/asfqqis2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/5ghn9pa0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72837', 'data', 'file=/tmp/tmps3g8rtu5/asfqqis2.json', 'init=/tmp/tmps3g8rtu5/5ghn9pa0.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_model8q5fwnri/prophet_model-20230411230953.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:09:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/v53krjvu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/2t8ijugf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72418', 'data', 'file=/tmp/tmps3g8rtu5/v53krjvu.json', 'init=/tmp/tmps3g8rtu5/2t8ijugf.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modeltjjlz2wy/prophet_model-20230411230953.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:09:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/5gq6sgr3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/1m7_mz8j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86793', 'data', 'file=/tmp/tmps3g8rtu5/5gq6sgr3.json', 'init=/tmp/tmps3g8rtu5/1m7_mz8j.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_model8li65t4p/prophet_model-20230411230954.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:09:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/h3efee_2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/0ug0_2c3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=10493', 'data', 'file=/tmp/tmps3g8rtu5/h3efee_2.json', 'init=/tmp/tmps3g8rtu5/0ug0_2c3.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modeljaq5cor0/prophet_model-20230411230954.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:09:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/iphqvu8n.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/o6qsrg89.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77827', 'data', 'file=/tmp/tmps3g8rtu5/iphqvu8n.json', 'init=/tmp/tmps3g8rtu5/o6qsrg89.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modeljmyj00j9/prophet_model-20230411230954.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:09:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/ob61wroo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/regyg8tx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30981', 'data', 'file=/tmp/tmps3g8rtu5/ob61wroo.json', 'init=/tmp/tmps3g8rtu5/regyg8tx.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_model_mco500x/prophet_model-20230411230954.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:09:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/a8xahjpm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/86xyak2h.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16928', 'data', 'file=/tmp/tmps3g8rtu5/a8xahjpm.json', 'init=/tmp/tmps3g8rtu5/86xyak2h.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modelmbtp3uov/prophet_model-20230411230954.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:09:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/tcbd3c51.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/7xbx5204.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67013', 'data', 'file=/tmp/tmps3g8rtu5/tcbd3c51.json', 'init=/tmp/tmps3g8rtu5/7xbx5204.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modelq_6_9c9z/prophet_model-20230411230954.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:09:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/ssw2sw9j.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/sq7n0g7h.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78558', 'data', 'file=/tmp/tmps3g8rtu5/ssw2sw9j.json', 'init=/tmp/tmps3g8rtu5/sq7n0g7h.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_model1nqa5yhs/prophet_model-20230411230955.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:09:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/dtmksb2n.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5/8a4osq0a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.9/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43443', 'data', 'file=/tmp/tmps3g8rtu5/dtmksb2n.json', 'init=/tmp/tmps3g8rtu5/8a4osq0a.json', 'output', 'file=/tmp/tmps3g8rtu5/prophet_modelrctvok5s/prophet_model-20230411230955.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:09:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:09:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmps3g8rtu5
csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:13:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:13:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#           ds       yhat
# 0 2017-12-18  53.406188
# 1 2017-12-19  53.607782
# 2 2017-12-20  53.609407
# 3 2017-12-21  53.306160
# 4 2017-12-22  52.961331

# %%
def prep_prophet(prophet_pred, data1):
  prophet_pred = prophet_pred.rename(columns = {'ds': 'date'}).set_index('date')
  main_data = data1.join(prophet_pred,how = 'left')
  returned = main_data.loc['2018-01-01':'2023-02-01', 'yhat']
  return returned

goog_data = prep_prophet(Google_train_data, frames[0])[10:]
msft_train_data = prep_prophet(MSFT_train_data, frames[1])[10:1153]
msft_test_data = prep_prophet(MSFT_train_data, frames[1])[1153:]

# %%
goog_data
# Out:
# date
# 2018-01-17    56.631977
# 2018-01-18    56.558215
# 2018-01-19    56.654661
# 2018-01-22    55.888931
# 2018-01-23    55.628505
#                 ...
# 2023-01-26    85.521561
# 2023-01-27    85.589997
# 2023-01-30    89.389398
# 2023-01-31    89.435572
# 2023-02-01    89.760823
# Name: yhat, Length: 1270, dtype: float64

# %% [markdown]
# ##4.4 Hybrid Model

# %% [markdown]
#  ### 4.4.1 Define Training Data Using Ouputs from Standalone Models MSFT

# %%
#creating y_hybrid from y_train of the LSTM model
print(y_train.shape)
y_hybrid= y_train
print(y_train.shape, y_hybrid.shape)
print(goog_data.shape)
# Out:
# (1143, 1)
# (1143, 1) (1143, 1)
# (1270,)

# %%
X_train2.shape
# Out:
# (1133, 10, 2)

# %%
#verifying that outputs from both the LSTM and Prohet models match in size
LSTM_MSFT_yhat = testmodel('/content/StockPrice-Hybrid-Model-/Models/LSTM_model.h5', X_train)
print ("LSTM:", LSTM_MSFT_yhat.shape,"\n","Prophet:", msft_train_data.shape)

#merging the the outcomes from the LSTM model and the Prophet model

msft_hybrid = { 'MSFT_PROPHET':np.array(msft_train_data),  'LSTM':LSTM_MSFT_yhat.flatten()}
msft_hybrid_df = pd.DataFrame(msft_hybrid)
#scaling the MSFT_PROPHET column
scaler2 = MinMaxScaler()

reshaped_msft = msft_hybrid_df['MSFT_PROPHET'].to_numpy()
reshaped_msft= reshaped_msft.reshape(-1,1)

scaled_msft = scaler2.fit_transform(reshaped_msft)
msft_hybrid_df['MSFT_Pscaled'] = scaled_msft.flatten()
msft_hybrid_df=msft_hybrid_df.drop('MSFT_PROPHET', axis=1)

#verifying the transform
print("msft hybrid",msft_hybrid_df.shape)
#Defining the data for the hybrid training
X2_ft = np.array(msft_hybrid_df)
print("y_hybrid", y_hybrid.shape)

X_train2,y_train2 = lstm_split(msft_hybrid_df,y_hybrid,len(msft_hybrid_df))
print(y_train2.shape)
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 36/36 [==============================] - 0s 5ms/step
# LSTM: (1143, 1)
#  Prophet: (1143,)
# msft hybrid (1143, 2)
# y_hybrid (1143, 1)
# (1133, 1)

# %%
#LSTM Framework for the hybrid model
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import LSTM
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.metrics import Precision
from keras.optimizers import Adam
import keras_tuner


#Hybrid model architecture and training
LR = 0.01
EPOCH = 300
BATCH = 24
hybrid = Sequential()
hybrid.add(LSTM(units = 98, activation = "sigmoid", input_shape = (X_train2.shape[1], X_train2.shape[2]), return_sequences = False))
hybrid.add(Dropout(0.5))
hybrid.add(Dense(units =1))
hybrid.compile(loss = 'mean_squared_error', optimizer = Adam(lr = LR), metrics = ["mae"])
Early_stop = EarlyStopping(monitor='loss', min_delta=0, 
                           patience=25, verbose=1, mode='auto',
                           baseline=0, restore_best_weights=True)

hybrid_history = hybrid.fit(X_train2, y_train2, epochs = EPOCH, batch_size = BATCH, callbacks = [Early_stop])

hybrid_history.model.save('/content/StockPrice-Hybrid-Model-/Models/Hybrid_model1.h5')
# Out:
# Epoch 1/300
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 48/48 [==============================] - 2s 10ms/step - loss: 0.2344 - mae: 0.3640
# Epoch 2/300
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0700 - mae: 0.2115
# Epoch 3/300
# 48/48 [==============================] - 1s 14ms/step - loss: 0.0433 - mae: 0.1647
# Epoch 4/300
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0230 - mae: 0.1210
# Epoch 5/300
# 48/48 [==============================] - 1s 12ms/step - loss: 0.0165 - mae: 0.1001
# Epoch 6/300
# 48/48 [==============================] - 1s 13ms/step - loss: 0.0143 - mae: 0.0947
# Epoch 7/300
# 48/48 [==============================] - 1s 21ms/step - loss: 0.0126 - mae: 0.0878
# Epoch 8/300
# 48/48 [==============================] - 1s 19ms/step - loss: 0.0108 - mae: 0.0814
# Epoch 9/300
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0101 - mae: 0.0781
# Epoch 10/300
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0085 - mae: 0.0724
# Epoch 11/300
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0078 - mae: 0.0695
# Epoch 12/300
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0083 - mae: 0.0713
# Epoch 13/300
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0074 - mae: 0.0677
# Epoch 14/300
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0070 - mae: 0.0659
# Epoch 15/300
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0060 - mae: 0.0609
# Epoch 16/300
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0061 - mae: 0.0599
# Epoch 17/300
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0056 - mae: 0.0578
# Epoch 18/300
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0052 - mae: 0.0556
# Epoch 19/300
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0049 - mae: 0.0539
# Epoch 20/300
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0060 - mae: 0.0610
# Epoch 21/300
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0059 - mae: 0.0596
# Epoch 22/300
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0047 - mae: 0.0532
# Epoch 23/300
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0042 - mae: 0.0509
# Epoch 24/300
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0045 - mae: 0.0521
# Epoch 25/300
# 48/48 [==============================] - ETA: 0s - loss: 0.0048 - mae: 0.0536Restoring model weights from the end of the best epoch: 23.
# 48/48 [==============================] - 0s 8ms/step - loss: 0.0048 - mae: 0.0536
# Epoch 25: early stopping

# %% [markdown]
# ###4.4.2 LOSS and MAE

# %%
import matplotlib.pyplot as plt

# plot MAE and loss
#plt.figure(figsize=(10, 6))
plt.plot(hybrid_history.history['mae'], label='MAE')
plt.plot(hybrid_history.history['loss'], label='loss')
plt.title(" Hybrid MSE vs MAE During Training")
plt.xlabel('epoch')
plt.legend()
plt.show()

# %% [markdown]
# ### 4.4.3 Comparing output of LSTM MSFT and Hybrid MSFT

# %% [markdown]
# ###4.4.4 Hybrid Model Testing on GOOG

# %%
#merge lstm test prediction and prophet test prediction
def merge_predictions(lstm_pred,prophet_pred):
  data_dict = {}
  scaler = MinMaxScaler()
  data_dict['LSTM'] = lstm_pred.flatten()
  data_dict['prophet'] = np.array(prophet_pred)
  hybrid_test_data = pd.DataFrame(data_dict)
  hybrid_test_data['prophet'] = scaler.fit_transform(hybrid_test_data[['prophet']])
  return hybrid_test_data

# %%
from keras.models import load_model
MSFT_test_hybrid = merge_predictions(LSTM_MSFT_test, msft_test_data)
MSFT_x_test, MSFT_y_test = lstm_split(MSFT_test_hybrid, y_test, len(MSFT_test_hybrid))
MSFT_predictions = testmodel('/content/StockPrice-Hybrid-Model-/Models/Hybrid_model1.h5', MSFT_x_test)
# Out:
# 4/4 [==============================] - 0s 5ms/step

# %%
print(LSTM_GOOG_yhat.shape,goog_data.shape)
GOOG_test_hybrid= merge_predictions(LSTM_GOOG_yhat, goog_data)
GOOG_x_test, GOOG_y_test = lstm_split(GOOG_test_hybrid,google_target,len(GOOG_test_hybrid))
GOOG_predictions = testmodel('/content/StockPrice-Hybrid-Model-/Models/Hybrid_model1.h5', GOOG_x_test)
# Out:
# (1270, 1) (1270,)
# 40/40 [==============================] - 0s 3ms/step

# %%
GOOG_predictions.shape,goog_data.shape
# Out:
# ((1260, 1), (1270,))

# %%
#ploting MSFT LSTM vs Hybrid predictions
import matplotlib.pyplot as plt
hybrid_MSFT_predictions = hybrid1.model.predict(hybrid_val_feat)

x=np.arange(1,len(LSTM_validation[10:])+1,1)
plt.plot(x, LSTM_validation[10:], "r", label= "LSTM")
plt.plot(x,hybrid_MSFT_predictions, "g", label= "Hybrid")
plt.plot(x,y_test[10:], "b", label= "Target")

plt.title(" MSFT  LSTM vs Hybrid trends")
plt.xlabel('X_test entry')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
x=np.arange(1,len(MSFT_y_test)+1, 1)
plt.plot(x,MSFT_predictions.flatten(), "r", label= "Predicted")
plt.plot(x,MSFT_y_test, "b", label= "Target")

plt.title(" Hybrid Microsft Predicted vs target trends")
plt.xlabel('X_test entry')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
x=np.arange(1,len(GOOG_y_test)+1, 1)
plt.plot(x,GOOG_predictions.flatten(), "r", label= "Predicted")
plt.plot(x,GOOG_y_test, "b", label= "Target")

plt.title(" Hybrid Google Predicted vs target trends")
plt.xlabel('X_test entry')
plt.legend()
plt.show()

# %%
def compute_metrics(true_series, forecast):
    """Helper to print MSE and MAE"""
    mse = tf.keras.metrics.MeanSquaredError()
    mse.update_state(true_series, forecast)
    mae = tf.keras.metrics.MeanAbsoluteError()
    mae.update_state(true_series, forecast)

    return mse.result().numpy(), mae.result().numpy()

# %%
import matplotlib.pyplot as plt
x=np.arange(1,len(GOOG_y_test)+1, 1)
plt.plot(GOOG_predictions.flatten(), "r", label= "Hybrid")
plt.plot(LSTM_GOOG_yhat, "b", label= "LSTM")
plt.plot(GOOG_y_test, "g", label= "Actual")

plt.title(" Hybrid predictions vs LSTM predictions vs Actual predictions for Google")
plt.xlabel('X_test entry')
plt.legend()
plt.show()

# %% [markdown]
# ###4.4.5 Model Scores

# %%
hybrid_mse, hybrid_mae = compute_metrics(GOOG_y_test, GOOG_predictions)
lstm_mse,lstm_mae = compute_metrics(google_target, LSTM_GOOG_yhat)
print("Mean Squared error for Hybrid model:{}".format(hybrid_mse))
print("Mean Absolute error for Hybrid model:{}".format(hybrid_mae))
print("Mean Squared error for LSTM model:{}".format(lstm_mse))
print("Mean Absolute error for LSTM model:{}".format(lstm_mae))
# Out:
# Mean Squared error for Hybrid model:0.00491330586373806
# Mean Absolute error for Hybrid model:0.06046774238348007
# Mean Squared error for LSTM model:0.0015894242096692324
# Mean Absolute error for LSTM model:0.03216106817126274

# %% [markdown]
# ###4.4.5 Predicted vs Actual Price

# %%
plt.plot(GOOG_y_test, label="actual")
plt.plot(GOOG_predictions, label="predicted")
plt.xlabel("Timesteps")
plt.ylabel("Value")
plt.tight_layout()
sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.legend()
plt.show()

# %% [markdown]
# ## Return Predictions to Original Scale for Final Analysis

# %%
GOOG_scaler = 
MSFT_scaler =

# %% [markdown]
# #5.0 Multiple Company Model

# %% [markdown]
# ## 5.1 Generate Sub-models

# %%
def create_lists(list_of_df):
  training_list = []
  target_list = []
  for i in range(len(list_of_df)):
    scaler = MinMaxScaler()
    data = list_of_df[i]
    score = data['score']
    target = scaler.fit_transform(data[['target']])
    training = data.drop(['target', 'ticker', 'score'], axis = 1)
    for col in training.columns:
      training[col] = scaler.fit_transform(training[[col]])
    training['score'] = score
    data_x, data_y = lstm_split(training, target, len(training))
    training_list.append(data_x)
    target_list.append(data_y)
  return training_list, target_list

#General LSTM model based on randomsearch results
def multiple_models(x_train, y_train):
    hybrid = Sequential()
    hybrid.add(LSTM(units = 98, activation = "relu", input_shape = (x_train.shape[1], x_train.shape[2]), return_sequences = False))
    hybrid.add(Dropout(0.7))
    hybrid.add(Dense(units =1, activation = 'sigmoid'))
    hybrid.compile(loss = 'mean_squared_error', optimizer = Adam(lr = LR), metrics = ["mean_squared_error"])
    Early_stop = EarlyStopping(monitor='val_loss', min_delta=0, 
                              patience=25, verbose=1, mode='auto',
                              baseline=0, restore_best_weights=True)
    hybrid.fit(x_train, y_train, epochs = 200, batch_size = 24, callbacks = [Early_stop])
    return hybrid

training_list, target_list = create_lists(frames[1:])
for tick, x_train, y_train in zip(ticker_list, training_list, target_list):
  model = multiple_models(x_train, y_train)
  model.save('/content/StockPrice-Hybrid-Model-/sub_models/'+tick+'_lstm.h5')
# Out:
# Epoch 1/200
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0177 - mean_squared_error: 0.0177
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 2s 11ms/step - loss: 0.0176 - mean_squared_error: 0.0176
# Epoch 2/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0072 - mean_squared_error: 0.0072
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0072 - mean_squared_error: 0.0072
# Epoch 3/200
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0062 - mean_squared_error: 0.0062
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 4/200
# 48/53 [==========================>...] - ETA: 0s - loss: 0.0061 - mean_squared_error: 0.0061
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 5/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0050 - mean_squared_error: 0.0050
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0050 - mean_squared_error: 0.0050
# Epoch 6/200
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0064 - mean_squared_error: 0.0064
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 16ms/step - loss: 0.0064 - mean_squared_error: 0.0064
# Epoch 7/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0055 - mean_squared_error: 0.0055
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 16ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 8/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0059 - mean_squared_error: 0.0059
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 15ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 9/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0051 - mean_squared_error: 0.0051
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 10/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0046 - mean_squared_error: 0.0046
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 18ms/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 11/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0056 - mean_squared_error: 0.0056
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 13ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 12/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0051 - mean_squared_error: 0.0051
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 13/200
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0042 - mean_squared_error: 0.0042
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 14/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0041 - mean_squared_error: 0.0041
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0041 - mean_squared_error: 0.0041
# Epoch 15/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 16/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 17/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0051 - mean_squared_error: 0.0051
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 18/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 19/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0049 - mean_squared_error: 0.0049
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0049 - mean_squared_error: 0.0049
# Epoch 20/200
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 21/200
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0040 - mean_squared_error: 0.0040
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0040 - mean_squared_error: 0.0040
# Epoch 22/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0044 - mean_squared_error: 0.0044
# Epoch 23/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 24/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0039 - mean_squared_error: 0.0039
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 25/200
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 26/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0047 - mean_squared_error: 0.0047
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 27/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0047 - mean_squared_error: 0.0047
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 14ms/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 28/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0047 - mean_squared_error: 0.0047
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 16ms/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 29/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0040 - mean_squared_error: 0.0040
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 22ms/step - loss: 0.0041 - mean_squared_error: 0.0041
# Epoch 30/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0037 - mean_squared_error: 0.0037
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0036 - mean_squared_error: 0.0036
# Epoch 31/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0036 - mean_squared_error: 0.0036
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0035 - mean_squared_error: 0.0035
# Epoch 32/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0039 - mean_squared_error: 0.0039
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 18ms/step - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 33/200
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0041 - mean_squared_error: 0.0041
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0041 - mean_squared_error: 0.0041
# Epoch 34/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0042 - mean_squared_error: 0.0042
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 35/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0040 - mean_squared_error: 0.0040
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0040 - mean_squared_error: 0.0040
# Epoch 36/200
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 37/200
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0040 - mean_squared_error: 0.0040
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0040 - mean_squared_error: 0.0040
# Epoch 38/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0040 - mean_squared_error: 0.0040
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0040 - mean_squared_error: 0.0040
# Epoch 39/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0046 - mean_squared_error: 0.0046
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 40/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0040 - mean_squared_error: 0.0040
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0040 - mean_squared_error: 0.0040
# Epoch 41/200
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0038 - mean_squared_error: 0.0038
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0038 - mean_squared_error: 0.0038
# Epoch 42/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0041 - mean_squared_error: 0.0041
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0041 - mean_squared_error: 0.0041
# Epoch 43/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0040 - mean_squared_error: 0.0040
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 44/200
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0033 - mean_squared_error: 0.0033
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0033 - mean_squared_error: 0.0033
# Epoch 45/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0039 - mean_squared_error: 0.0039
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0038 - mean_squared_error: 0.0038
# Epoch 46/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0039 - mean_squared_error: 0.0039
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 47/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0038 - mean_squared_error: 0.0038
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0038 - mean_squared_error: 0.0038
# Epoch 48/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0042 - mean_squared_error: 0.0042
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 49/200
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0038 - mean_squared_error: 0.0038
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0038 - mean_squared_error: 0.0038
# Epoch 50/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0036 - mean_squared_error: 0.0036
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 13ms/step - loss: 0.0036 - mean_squared_error: 0.0036
# Epoch 51/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0039 - mean_squared_error: 0.0039
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 15ms/step - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 52/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 16ms/step - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 53/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0041 - mean_squared_error: 0.0041
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 18ms/step - loss: 0.0041 - mean_squared_error: 0.0041
# Epoch 54/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0048 - mean_squared_error: 0.0048
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 18ms/step - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 55/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0040 - mean_squared_error: 0.0040
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 18ms/step - loss: 0.0041 - mean_squared_error: 0.0041
# Epoch 56/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0038 - mean_squared_error: 0.0038
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 14ms/step - loss: 0.0038 - mean_squared_error: 0.0038
# Epoch 57/200
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0038 - mean_squared_error: 0.0038
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0037 - mean_squared_error: 0.0037
# Epoch 58/200
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0047 - mean_squared_error: 0.0047
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 59/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 60/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0042 - mean_squared_error: 0.0042
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 61/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0041 - mean_squared_error: 0.0041
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0041 - mean_squared_error: 0.0041
# Epoch 62/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0046 - mean_squared_error: 0.0046
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 63/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0039 - mean_squared_error: 0.0039
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 64/200
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 65/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 66/200
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0038 - mean_squared_error: 0.0038
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0038 - mean_squared_error: 0.0038
# Epoch 67/200
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0040 - mean_squared_error: 0.0040
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0041 - mean_squared_error: 0.0041
# Epoch 68/200
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 69/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0046 - mean_squared_error: 0.0046
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 13ms/step - loss: 0.0046 - mean_squared_error: 0.0046
# Epoch 70/200
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0038 - mean_squared_error: 0.0038
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0038 - mean_squared_error: 0.0038
# Epoch 71/200
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0042 - mean_squared_error: 0.0042
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 72/200
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0041 - mean_squared_error: 0.0041
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 15ms/step - loss: 0.0040 - mean_squared_error: 0.0040
# Epoch 73/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0042 - mean_squared_error: 0.0042
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 74/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0040 - mean_squared_error: 0.0040
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0041 - mean_squared_error: 0.0041
# Epoch 75/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0044 - mean_squared_error: 0.0044
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 76/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0042 - mean_squared_error: 0.0042
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0041 - mean_squared_error: 0.0041
# Epoch 77/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0038 - mean_squared_error: 0.0038
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0038 - mean_squared_error: 0.0038
# Epoch 78/200
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0037 - mean_squared_error: 0.0037
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 13ms/step - loss: 0.0036 - mean_squared_error: 0.0036
# Epoch 79/200
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0039 - mean_squared_error: 0.0039
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 80/200
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0036 - mean_squared_error: 0.0036
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0037 - mean_squared_error: 0.0037
# Epoch 81/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0042 - mean_squared_error: 0.0042
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 82/200
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0037 - mean_squared_error: 0.0037
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 10ms/step - loss: 0.0037 - mean_squared_error: 0.0037
# Epoch 83/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0042 - mean_squared_error: 0.0042
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 84/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0041 - mean_squared_error: 0.0041
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0041 - mean_squared_error: 0.0041
# Epoch 85/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0038 - mean_squared_error: 0.0038
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 86/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0037 - mean_squared_error: 0.0037
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.0037 - mean_squared_error: 0.0037
# Epoch
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 11ms/step - loss: 0.2639 - mean_squared_error: 0.2639
# Epoch 139/200
# 49/53 [==========================>...] - ETA: 0s - loss: 0.2654 - mean_squared_error: 0.2654
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 12ms/step - loss: 0.2633 - mean_squared_error: 0.2633
# Epoch 140/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.2642 - mean_squared_error: 0.2642
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# ...
# 53/53 [==============================] - 1s 13ms/step - loss: 0.0040 - mean_squared_error: 0.0040
# Epoch 155/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 13ms/step - loss: 0.0043 - mean_squared_error: 0.0043
# Epoch 156/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0036 - mean_squared_error: 0.0036
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 15ms/step - loss: 0.0036 - mean_squared_error: 0.0036
# Epoch 157/200
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0039 - mean_squared_error: 0.0039
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 14ms/step - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 158/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 159/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0046 - mean_squared_error: 0.0046
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 160/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0039 - mean_squared_error: 0.0039
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 161/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0043 - mean_squared_error: 0.0043
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 162/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0041 - mean_squared_error: 0.0041
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0041 - mean_squared_error: 0.0041
# Epoch 163/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0037 - mean_squared_error: 0.0037
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0037 - mean_squared_error: 0.0037
# Epoch 164/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0039 - mean_squared_error: 0.0039
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 165/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0042 - mean_squared_error: 0.0042
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0042 - mean_squared_error: 0.0042
# Epoch 166/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0040 - mean_squared_error: 0.0040
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0040 - mean_squared_error: 0.0040
# Epoch 167/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0047 - mean_squared_error: 0.0047
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0047 - mean_squared_error: 0.0047
# Epoch 168/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0045 - mean_squared_error: 0.0045
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 14ms/step - loss: 0.0045 - mean_squared_error: 0.0045
# Epoch 169/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0105 - mean_squared_error: 0.0105
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 15ms/step - loss: 0.0105 - mean_squared_error: 0.0105
# Epoch 170/200
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 15ms/step - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 171/200
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0082 - mean_squared_error: 0.0082
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 13ms/step - loss: 0.0081 - mean_squared_error: 0.0081
# Epoch 172/200
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0070 - mean_squared_error: 0.0070
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 13ms/step - loss: 0.0070 - mean_squared_error: 0.0070
# Epoch 173/200
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0075 - mean_squared_error: 0.0075
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 14ms/step - loss: 0.0075 - mean_squared_error: 0.0075
# Epoch 174/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0060 - mean_squared_error: 0.0060
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 14ms/step - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 175/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0065 - mean_squared_error: 0.0065
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 15ms/step - loss: 0.0065 - mean_squared_error: 0.0065
# Epoch 176/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0063 - mean_squared_error: 0.0063
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 14ms/step - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 177/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0063 - mean_squared_error: 0.0063
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 13ms/step - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 178/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0058 - mean_squared_error: 0.0058
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 14ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 179/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0055 - mean_squared_error: 0.0055
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 14ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 180/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0061 - mean_squared_error: 0.0061
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 16ms/step - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 181/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0056 - mean_squared_error: 0.0056
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 20ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 182/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0060 - mean_squared_error: 0.0060
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 183/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0058 - mean_squared_error: 0.0058
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 21ms/step - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 184/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0053 - mean_squared_error: 0.0053
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 185/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0056 - mean_squared_error: 0.0056
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 186/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0055 - mean_squared_error: 0.0055
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 187/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0056 - mean_squared_error: 0.0056
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 19ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 188/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0050 - mean_squared_error: 0.0050
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 17ms/step - loss: 0.0052 - mean_squared_error: 0.0052
# Epoch 189/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0062 - mean_squared_error: 0.0062
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 14ms/step - loss: 0.0062 - mean_squared_error: 0.0062
# Epoch 190/200
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0059 - mean_squared_error: 0.0059
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 14ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 191/200
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0054 - mean_squared_error: 0.0054
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 14ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 192/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0058 - mean_squared_error: 0.0058
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 13ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 193/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0054 - mean_squared_error: 0.0054
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 14ms/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 194/200
# 49/53 [==========================>...] - ETA: 0s - loss: 0.0056 - mean_squared_error: 0.0056
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 13ms/step - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 195/200
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0061 - mean_squared_error: 0.0061
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 13ms/step - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 196/200
# 50/53 [===========================>..] - ETA: 0s - loss: 0.0055 - mean_squared_error: 0.0055
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 15ms/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 197/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0057 - mean_squared_error: 0.0057
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 13ms/step - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 198/200
# 52/53 [============================>.] - ETA: 0s - loss: 0.0079 - mean_squared_error: 0.0079
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 13ms/step - loss: 0.0079 - mean_squared_error: 0.0079
# Epoch 199/200
# 53/53 [==============================] - ETA: 0s - loss: 0.0061 - mean_squared_error: 0.0061
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 14ms/step - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 200/200
# 51/53 [===========================>..] - ETA: 0s - loss: 0.0069 - mean_squared_error: 0.0069
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 53/53 [==============================] - 1s 13ms/step - loss: 0.0069 - mean_squared_error: 0.0069

# %% [markdown]
# ### 5.1.1 Configure Hybrid Training Set and Train Hybrid Model

# %%
import os

def hybrid_train(direct, ticker_list, hybrid_train, prophet, targets):
    preds_dict = {}
    path = direct
    scaler = MinMaxScaler()
    for num, model in enumerate(os.listdir(path)):
        model = load_model(path+model)
        prediction = model.predict(hybrid_train).flatten()
        preds_dict[ticker_list[num]] = prediction
    preds_df = pd.DataFrame(preds_dict)
    preds_df['prophet'] = np.array(prophet)
    preds_df['prophet'] = scaler.fit_transform(preds_df[['prophet']])
    x1,y1 = lstm_split(preds_df, targets, len(preds_df))
    return x1, y1

ticker_list = ["MSFT", "NFLX", "AMZN", "TSLA"]
hybrid_training_data, targets =  hybrid_train('/content/StockPrice-Hybrid-Model-/sub_models/', ticker_list, X_train, msft_train_data, y_train) 
hybrid_expanded = multiple_models(hybrid_training_data, targets)
# Out:
# 36/36 [==============================] - 0s 4ms/step
# 36/36 [==============================] - 0s 4ms/step
# 36/36 [==============================] - 0s 4ms/step
# 36/36 [==============================] - 0s 4ms/step
# Epoch 1/200
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 43/48 [=========================>....] - ETA: 0s - loss: 0.
200
# 47/48 [============================>.] - ETA: 0s - loss: 0.0330 - mean_squared_error: 0.0330
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 48/48 [==============================] - 1s 15ms/step - loss: 0.0328 - mean_squared_error: 0.0328
# Epoch 182/200
# 48/48 [==============================] - ETA: 0s - loss: 0.0327 - mean_squared_error: 0.0327
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 48/48 [==============================] - 1s 14ms/step - loss: 0.0327 - mean_squared_error: 0.0327
# Epoch 183/200
# 47/48 [============================>.] - ETA: 0s - loss: 0.0330 - mean_squared_error: 0.0330
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 48/48 [==============================] - 1s 15ms/step - loss: 0.0329 - mean_squared_error: 0.0329
# Epoch 184/200
# 48/48 [==============================] - ETA: 0s - loss: 0.0332 - mean_squared_error: 0.0332
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 48/48 [==============================] - 1s 14ms/step - loss: 0.0332 - mean_squared_error: 0.0332
# Epoch 185/200
# 45/48 [===========================>..] - ETA: 0s - loss: 0.0325 - mean_squared_error: 0.0325
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0329 - mean_squared_error: 0.0329
# Epoch 186/200
# 44/48 [==========================>...] - ETA: 0s - loss: 0.0331 - mean_squared_error: 0.0331
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 48/48 [==============================] - 1s 10ms/step - loss: 0.0328 - mean_squared_error: 0.0328
# Epoch 187/200
# 46/48 [===========================>..] - ETA: 0s - loss: 0.0332 - mean_squared_error: 0.0332
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0334 - mean_squared_error: 0.0334
# Epoch 188/200
# 46/48 [===========================>..] - ETA: 0s - loss: 0.0333 - mean_squared_error: 0.0333
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0328 - mean_squared_error: 0.0328
# Epoch 189/200
# 44/48 [==========================>...] - ETA: 0s - loss: 0.0320 - mean_squared_error: 0.0320
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0329 - mean_squared_error: 0.0329
# Epoch 190/200
# 47/48 [============================>.] - ETA: 0s - loss: 0.0329 - mean_squared_error: 0.0329
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0328 - mean_squared_error: 0.0328
# Epoch 191/200
# 46/48 [===========================>..] - ETA: 0s - loss: 0.0324 - mean_squared_error: 0.0324
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 48/48 [==============================] - 1s 10ms/step - loss: 0.0327 - mean_squared_error: 0.0327
# Epoch 192/200
# 44/48 [==========================>...] - ETA: 0s - loss: 0.0333 - mean_squared_error: 0.0333
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0328 - mean_squared_error: 0.0328
# Epoch 193/200
# 45/48 [===========================>..] - ETA: 0s - loss: 0.0322 - mean_squared_error: 0.0322
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0328 - mean_squared_error: 0.0328
# Epoch 194/200
# 48/48 [==============================] - ETA: 0s - loss: 0.0331 - mean_squared_error: 0.0331
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0331 - mean_squared_error: 0.0331
# Epoch 195/200
# 44/48 [==========================>...] - ETA: 0s - loss: 0.0331 - mean_squared_error: 0.0331
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0331 - mean_squared_error: 0.0331
# Epoch 196/200
# 45/48 [===========================>..] - ETA: 0s - loss: 0.0312 - mean_squared_error: 0.0312
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0326 - mean_squared_error: 0.0326
# Epoch 197/200
# 45/48 [===========================>..] - ETA: 0s - loss: 0.0335 - mean_squared_error: 0.0335
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0334 - mean_squared_error: 0.0334
# Epoch 198/200
# 44/48 [==========================>...] - ETA: 0s - loss: 0.0322 - mean_squared_error: 0.0322
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 48/48 [==============================] - 1s 11ms/step - loss: 0.0329 - mean_squared_error: 0.0329
# Epoch 199/200
# 44/48 [==========================>...] - ETA: 0s - loss: 0.0335 - mean_squared_error: 0.0335
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 48/48 [==============================] - 1s 10ms/step - loss: 0.0329 - mean_squared_error: 0.0329
# Epoch 200/200
# 46/48 [===========================>..] - ETA: 0s - loss: 0.0336 - mean_squared_error: 0.0336
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mean_squared_error
# 48/48 [==============================] - 0s 10ms/step - loss: 0.0330 - mean_squared_error: 0.0330

# %%
hybrid_expanded.save('/content/StockPrice-Hybrid-Model-/Models/hybrid_expanded.h5')

# %% [markdown]
# ### 5.1.2 Test the Expanded Model

# %%
from os import listdir
hybrid_expanded = load_model('/content/StockPrice-Hybrid-Model-/Models/hybrid_expanded.h5')
google_test = {}
microsoft_test = {}
path = '/content/StockPrice-Hybrid-Model-/sub_models/'
for num, model in enumerate(os.listdir(path)):
  scaler = MinMaxScaler()
  model = load_model(path+model)
  goog_preds = model.predict(google_ft).flatten()
  micro_preds = model.predict(X_test).flatten()
  google_test[ticker_list[num]] = goog_preds
  microsoft_test[ticker_list[num]] = micro_preds
google_test = pd.DataFrame(google_test)
microsoft_test = pd.DataFrame(microsoft_test)

google_test['prophet'] = np.array(goog_data)
google_test['prophet'] = scaler.fit_transform(google_test[['prophet']])
microsoft_test['prophet'] = np.array(msft_test_data)
microsoft_test['prophet'] = scaler.fit_transform(microsoft_test[['prophet']])

goog_x, goog_y = lstm_split(google_test, google_target, len(google_test))
msft_x, msft_y = lstm_split(microsoft_test, y_test, len(microsoft_test))
# Out:
# 40/40 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 40/40 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 6ms/step
# 40/40 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step
# 40/40 [==============================] - 0s 5ms/step
# 4/4 [==============================] - 0s 5ms/step

# %%
goog_predictions = hybrid_expanded.predict(goog_x)
msft_predictions = hybrid_expanded.predict(msft_x)
# Out:
# 40/40 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 5ms/step

# %%
import matplotlib.pyplot as plt

# plot MAE and loss
#plt.figure(figsize=(10, 6))
plt.plot(hybrid_history.history['mae'], label='MAE')
plt.plot(hybrid_history.history['loss'], label='loss')
plt.xlabel('epoch')
plt.legend()
plt.show()

# compare LSTM on trained on MSFT on predictions for Google
fig, ax = plt.subplots()
ax.plot(LSTM_MSFT_yhat, 'g')
ax.plot(LSTM_GOOG_yhat, 'b')
plt.show()
